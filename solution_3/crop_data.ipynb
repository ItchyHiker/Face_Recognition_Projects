# %%
import os
import glob

import cv2
import torch
torch.multiprocessing.set_start_method('spawn')
from mtcnn.detector import MtcnnDetector
from deepblue_align_mtcnn import process

# %%
from multiprocessing import set_start_method
try:
    set_start_method('spawn')
except RuntimeError:
    pass

# %%
torch.version.cuda
torch.cuda.current_device()
torch.cuda.is_available()
torch.cuda.get_device_name(1)
# Out:
# 'TITAN Xp'

# %%
data = torch.Tensor([0, 1])
print(data.shape)
data.cuda()
# Out:
# torch.Size([2])
# tensor([0., 1.], device='cuda:0')

# %%
casia_data_path = './data/CASIA-WebFace/'
lfw_data_path = './data/lfw'

casia_persons = [f for f in os.listdir(casia_data_path)]
lfw_persons = [f for f in os.listdir(lfw_data_path)]

# %%
num_persons = len(lfw_persons)

# %%
num_persons
# Out:
# 5749

# %%
images = glob.glob('./data/lfw/*/*.jpg')

# %%
len(images)
# Out:
# 13233

# %%
ls data/lfw/Abdullah_Gul/
# Out:
# Abdullah_Gul_0001.jpg  Abdullah_Gul_0008.jpg  Abdullah_Gul_0015.jpg
# Abdullah_Gul_0002.jpg  Abdullah_Gul_0009.jpg  Abdullah_Gul_0016.jpg
# Abdullah_Gul_0003.jpg  Abdullah_Gul_0010.jpg  Abdullah_Gul_0017.jpg
# Abdullah_Gul_0004.jpg  Abdullah_Gul_0011.jpg  Abdullah_Gul_0018.jpg
# Abdullah_Gul_0005.jpg  Abdullah_Gul_0012.jpg  Abdullah_Gul_0019.jpg
# Abdullah_Gul_0006.jpg  Abdullah_Gul_0013.jpg
# Abdullah_Gul_0007.jpg  Abdullah_Gul_0014.jpg

# %%
detector = MtcnnDetector()
trainingdata_path = 'training_data/train'

# %%
for person in sorted(casia_persons):
    print(person)
    dst_data_path = os.path.join(trainingdata_path, person)
    if not os.path.exists(dst_data_path):
        os.makedirs(dst_data_path)
    images_path = os.path.join(casia_data_path, person)
    images = [f for f in os.listdir(images_path) if f.endswith('.jpg')]
    print(images)
    for image_file in images:
        print( os.path.join(images_path, image_file))
        process(detector, os.path.join(images_path, image_file), 'unlabelled', (112, 112), save_path=dst_data_path)
# Out:
# 0000045
# ['002.jpg', '005.jpg', '001.jpg', '015.jpg', '006.jpg', '009.jpg', '004.jpg', '011.jpg', '013.jpg', '010.jpg', '014.jpg', '003.jpg', '012.jpg', '007.jpg', '008.jpg']
# ./data/CASIA-WebFace/0000045/002.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 002.jpg
# ./data/CASIA-WebFace/0000045/005.jpg
# 7
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 005.jpg
# ./data/CASIA-WebFace/0000045/001.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 001.jpg
# ./data/CASIA-WebFace/0000045/015.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 015.jpg
# ./data/CASIA-WebFace/0000045/006.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 006.jpg
# ./data/CASIA-WebFace/0000045/009.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 009.jpg
# ./data/CASIA-WebFace/0000045/004.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 004.jpg
# ./data/CASIA-WebFace/0000045/011.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 011.jpg
# ./data/CASIA-WebFace/0000045/013.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 013.jpg
# ./data/CASIA-WebFace/0000045/010.jpg
# 7
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 010.jpg
# ./data/CASIA-WebFace/0000045/014.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 014.jpg
# ./data/CASIA-WebFace/0000045/003.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 003.jpg
# ./data/CASIA-WebFace/0000045/012.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 012.jpg
# ./data/CASIA-WebFace/0000045/007.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 007.jpg
# 007.jpg
# ./data/CASIA-WebFace/0000045/008.jpg
# 8
# training_data/train/0000045
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
#
jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 167.jpg
# ./data/CASIA-WebFace/0000099/062.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 062.jpg
# ./data/CASIA-WebFace/0000099/155.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 155.jpg
# ./data/CASIA-WebFace/0000099/103.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 103.jpg
# ./data/CASIA-WebFace/0000099/168.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 168.jpg
# ./data/CASIA-WebFace/0000099/031.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 031.jpg
# ./data/CASIA-WebFace/0000099/124.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 124.jpg
# ./data/CASIA-WebFace/0000099/105.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 105.jpg
# ./data/CASIA-WebFace/0000099/248.jpg
# 6
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 248.jpg
# ./data/CASIA-WebFace/0000099/182.jpg
# 7
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 182.jpg
# ./data/CASIA-WebFace/0000099/142.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 142.jpg
# ./data/CASIA-WebFace/0000099/072.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 072.jpg
# ./data/CASIA-WebFace/0000099/016.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 016.jpg
# ./data/CASIA-WebFace/0000099/074.jpg
# 7
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 074.jpg
# ./data/CASIA-WebFace/0000099/098.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 098.jpg
# ./data/CASIA-WebFace/0000099/187.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 187.jpg
# ./data/CASIA-WebFace/0000099/092.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 092.jpg
# ./data/CASIA-WebFace/0000099/186.jpg
# 4
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 186.jpg
# ./data/CASIA-WebFace/0000099/183.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 183.jpg
# ./data/CASIA-WebFace/0000099/002.jpg
# 5
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 002.jpg
# ./data/CASIA-WebFace/0000099/050.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 050.jpg
# ./data/CASIA-WebFace/0000099/053.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 053.jpg
# ./data/CASIA-WebFace/0000099/256.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 256.jpg
# ./data/CASIA-WebFace/0000099/032.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 032.jpg
# ./data/CASIA-WebFace/0000099/199.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 199.jpg
# ./data/CASIA-WebFace/0000099/005.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 005.jpg
# ./data/CASIA-WebFace/0000099/154.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 154.jpg
# ./data/CASIA-WebFace/0000099/001.jpg
# 7
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 001.jpg
# ./data/CASIA-WebFace/0000099/175.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 175.jpg
# ./data/CASIA-WebFace/0000099/108.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 108.jpg
# ./data/CASIA-WebFace/0000099/239.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 239.jpg
# ./data/CASIA-WebFace/0000099/201.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 201.jpg
# ./data/CASIA-WebFace/0000099/066.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 066.jpg
# ./data/CASIA-WebFace/0000099/148.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 148.jpg
# ./data/CASIA-WebFace/0000099/189.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 189.jpg
# ./data/CASIA-WebFace/0000099/234.jpg
# 7
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 234.jpg
# ./data/CASIA-WebFace/0000099/096.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 096.jpg
# ./data/CASIA-WebFace/0000099/093.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 093.jpg
# ./data/CASIA-WebFace/0000099/143.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 143.jpg
# ./data/CASIA-WebFace/0000099/119.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 119.jpg
# ./data/CASIA-WebFace/0000099/095.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 095.jpg
# ./data/CASIA-WebFace/0000099/257.jpg
# 7
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 257.jpg
# ./data/CASIA-WebFace/0000099/209.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 209.jpg
# ./data/CASIA-WebFace/0000099/017.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 017.jpg
# ./data/CASIA-WebFace/0000099/171.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 171.jpg
# ./data/CASIA-WebFace/0000099/161.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 161.jpg
# ./data/CASIA-WebFace/0000099/250.jpg
# 7
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 250.jpg
# ./data/CASIA-WebFace/0000099/162.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 162.jpg
# ./data/CASIA-WebFace/0000099/015.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 015.jpg
# ./data/CASIA-WebFace/0000099/146.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 146.jpg
# ./data/CASIA-WebFace/0000099/247.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 247.jpg
# ./data/CASIA-WebFace/0000099/138.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 138.jpg
# ./data/CASIA-WebFace/0000099/193.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 193.jpg
# 193.jpg
# ./data/CASIA-WebFace/0000099/229.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 229.jpg
# ./data/CASIA-WebFace/0000099/064.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 064.jpg
# ./data/CASIA-WebFace/0000099/097.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 097.jpg
# ./data/CASIA-WebFace/0000099/104.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 104.jpg
# ./data/CASIA-WebFace/0000099/127.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 127.jpg
# ./data/CASIA-WebFace/0000099/039.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 039.jpg
# ./data/CASIA-WebFace/0000099/242.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 242.jpg
# ./data/CASIA-WebFace/0000099/174.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 174.jpg
# ./data/CASIA-WebFace/0000099/213.jpg
# 4
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 213.jpg
# ./data/CASIA-WebFace/0000099/049.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 049.jpg
# ./data/CASIA-WebFace/0000099/249.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 249.jpg
# ./data/CASIA-WebFace/0000099/100.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 100.jpg
# ./data/CASIA-WebFace/0000099/081.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 081.jpg
# ./data/CASIA-WebFace/0000099/117.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 117.jpg
# ./data/CASIA-WebFace/0000099/006.jpg
# 6
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 006.jpg
# ./data/CASIA-WebFace/0000099/203.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 203.jpg
# ./data/CASIA-WebFace/0000099/244.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 244.jpg
# ./data/CASIA-WebFace/0000099/061.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 061.jpg
# ./data/CASIA-WebFace/0000099/136.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 136.jpg
# ./data/CASIA-WebFace/0000099/088.jpg
# 7
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 088.jpg
# ./data/CASIA-WebFace/0000099/080.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 080.jpg
# ./data/CASIA-WebFace/0000099/085.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 085.jpg
# ./data/CASIA-WebFace/0000099/211.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 211.jpg
# ./data/CASIA-WebFace/0000099/036.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 036.jpg
# ./data/CASIA-WebFace/0000099/207.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 207.jpg
# 207.jpg
# ./data/CASIA-WebFace/0000099/089.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 089.jpg
# ./data/CASIA-WebFace/0000099/073.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 073.jpg
# 073.jpg
# ./data/CASIA-WebFace/0000099/075.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 075.jpg
# ./data/CASIA-WebFace/0000099/027.jpg
# 5
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 027.jpg
# ./data/CASIA-WebFace/0000099/145.jpg
# 7
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 145.jpg
# ./data/CASIA-WebFace/0000099/156.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 156.jpg
# ./data/CASIA-WebFace/0000099/063.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 063.jpg
# ./data/CASIA-WebFace/0000099/082.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 082.jpg
# ./data/CASIA-WebFace/0000099/176.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 176.jpg
# ./data/CASIA-WebFace/0000099/057.jpg
# 7
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 057.jpg
# ./data/CASIA-WebFace/0000099/212.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 212.jpg
# ./data/CASIA-WebFace/0000099/177.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 177.jpg
# ./data/CASIA-WebFace/0000099/090.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 090.jpg
# ./data/CASIA-WebFace/0000099/243.jpg
# 7
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 243.jpg
# ./data/CASIA-WebFace/0000099/164.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 164.jpg
# ./data/CASIA-WebFace/0000099/041.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 041.jpg
# ./data/CASIA-WebFace/0000099/133.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 133.jpg
# ./data/CASIA-WebFace/0000099/254.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 254.jpg
# ./data/CASIA-WebFace/0000099/120.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 120.jpg
# ./data/CASIA-WebFace/0000099/009.jpg
# 6
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 009.jpg
# ./data/CASIA-WebFace/0000099/114.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 114.jpg
# ./data/CASIA-WebFace/0000099/140.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 140.jpg
# ./data/CASIA-WebFace/0000099/026.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 026.jpg
# ./data/CASIA-WebFace/0000099/122.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 122.jpg
# ./data/CASIA-WebFace/0000099/065.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 065.jpg
# ./data/CASIA-WebFace/0000099/045.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 045.jpg
# ./data/CASIA-WebFace/0000099/149.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 149.jpg
# ./data/CASIA-WebFace/0000099/210.jpg
# 7
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 210.jpg
# ./data/CASIA-WebFace/0000099/236.jpg
# 8
# training_data/train/0000099
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
# ...
# 364.jpg
# ./data/CASIA-WebFace/0000102/031.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 031.jpg
# ./data/CASIA-WebFace/0000102/392.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 392.jpg
# ./data/CASIA-WebFace/0000102/124.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 124.jpg
# ./data/CASIA-WebFace/0000102/105.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 105.jpg
# ./data/CASIA-WebFace/0000102/248.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 248.jpg
# ./data/CASIA-WebFace/0000102/267.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 267.jpg
# ./data/CASIA-WebFace/0000102/331.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 331.jpg
# ./data/CASIA-WebFace/0000102/182.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 182.jpg
# ./data/CASIA-WebFace/0000102/378.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 378.jpg
# ./data/CASIA-WebFace/0000102/359.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 359.jpg
# ./data/CASIA-WebFace/0000102/314.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 314.jpg
# ./data/CASIA-WebFace/0000102/263.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 263.jpg
# ./data/CASIA-WebFace/0000102/301.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 301.jpg
# ./data/CASIA-WebFace/0000102/291.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 291.jpg
# ./data/CASIA-WebFace/0000102/142.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 142.jpg
# ./data/CASIA-WebFace/0000102/072.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 072.jpg
# ./data/CASIA-WebFace/0000102/284.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 284.jpg
# ./data/CASIA-WebFace/0000102/016.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 016.jpg
# 016.jpg
# ./data/CASIA-WebFace/0000102/074.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 074.jpg
# ./data/CASIA-WebFace/0000102/098.jpg
# 7
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 098.jpg
# ./data/CASIA-WebFace/0000102/187.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 187.jpg
# ./data/CASIA-WebFace/0000102/092.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 092.jpg
# ./data/CASIA-WebFace/0000102/308.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 308.jpg
# ./data/CASIA-WebFace/0000102/186.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 186.jpg
# ./data/CASIA-WebFace/0000102/304.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 304.jpg
# ./data/CASIA-WebFace/0000102/288.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 288.jpg
# ./data/CASIA-WebFace/0000102/183.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 183.jpg
# ./data/CASIA-WebFace/0000102/002.jpg
# 7
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 002.jpg
# ./data/CASIA-WebFace/0000102/289.jpg
# 6
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 289.jpg
# ./data/CASIA-WebFace/0000102/278.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 278.jpg
# ./data/CASIA-WebFace/0000102/050.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 050.jpg
# ./data/CASIA-WebFace/0000102/053.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 053.jpg
# ./data/CASIA-WebFace/0000102/256.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 256.jpg
# ./data/CASIA-WebFace/0000102/032.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 032.jpg
# ./data/CASIA-WebFace/0000102/376.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 376.jpg
# ./data/CASIA-WebFace/0000102/351.jpg
# 7
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 351.jpg
# ./data/CASIA-WebFace/0000102/199.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 199.jpg
# ./data/CASIA-WebFace/0000102/353.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 353.jpg
# ./data/CASIA-WebFace/0000102/322.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 322.jpg
# ./data/CASIA-WebFace/0000102/374.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 374.jpg
# ./data/CASIA-WebFace/0000102/310.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 310.jpg
# ./data/CASIA-WebFace/0000102/005.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points
# 005.jpg
# 005.jpg
# ./data/CASIA-WebFace/0000102/154.jpg
# 8
# training_data/train/0000102
# ---> default:
#               crop_size =  [112 112]
#               reference_5pts =  [[38.29459953 51.69630051]
#  [73.53179932 51.50139999]
#  [56.02519989 71.73660278]
#  [41.54930115 92.3655014 ]
#  [70.72990036 92.20410156]]
# output_size == DEFAULT_CROP_SIZE [112 112]: return default reference points

# %%
ls training_data/train

# %%
image = cv2.imread('./data/CASIA-WebFace/0000102/292.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(image)
